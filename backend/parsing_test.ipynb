# %%
from bs4 import BeautifulSoup
import pandas as pd
with open("response.html", "rb") as f:
    soup = BeautifulSoup(f, "lxml")

# find all the screener root divs
roots = soup.find_all("div", class_="js-base-screener-page-component-root")

def table_to_records(table):
    headers = [th.get_text(strip=True) for th in table.select("thead th")]
    rows = []
    for tr in table.select("tbody tr"):
        cells = [td.get_text(strip=True) for td in tr.find_all("td")]
        rows.append(dict(zip(headers, cells)))
    return rows

all_records = []
for div in roots:
    table = div.find("table")
    if table:
        all_records.extend(table_to_records(table))

df = pd.DataFrame(all_records)

# %%
df
# Out:
#                                Symbol Rel Volume      Price  Change %  \
# 0              INHDInno Holdings Inc.   6,120.21    4.75USD  +262.60%
# 1              HCWBHCW Biologics Inc.   2,639.21    5.55USD   +60.82%
# 2          CAPSCapstone Holding Corp.     997.08    1.71USD   +55.45%
# 3                EPIXESSA Pharma Inc.     288.66  0.7838USD   −59.39%
# 4          STSSSharps Technology Inc.     244.83   10.35USD   +40.72%
# ..                                ...        ...        ...       ...
# 95       VENUVenu Holding Corporation       4.38   14.64USD   −18.35%
# 96       LEXXLexaria Bioscience Corp.       4.31    1.05USD   +32.44%
# 97  NCSMNCS Multistage Holdings, Inc.       4.26   39.49USD    +6.73%
# 98  SUPXSuper X AI Technology Limited       4.24   58.20USD   +35.85%
# 99          ENGSEnergys Group Limited       4.19    4.20USD    +5.00%
#
#       Volume   Market cap   P/E    EPS dilTTM EPS dil growthTTM YoY  \
# 0   193.82 M   36.81 MUSD     —      −1.47USD               +24.55%
# 1    87.69 M   11.94 MUSD     —     −16.07USD               +61.32%
# 2   105.02 M    9.54 MUSD     —     −14.13USD               +64.07%
# 3   178.45 M   37.08 MUSD     —      −0.57USD                +8.97%
# 4    24.82 M   10.59 MUSD     —  −1,000.36USD               +71.10%
# ..       ...          ...   ...           ...                   ...
# 95  283.54 K  595.72 MUSD     —      −1.04USD                     —
# 96  786.76 K   20.54 MUSD     —      −0.66USD               +41.28%
# 97   42.77 K  100.34 MUSD  8.28       4.77USD               −72.21%
# 98  823.13 K    1.29 BUSD     —             —                     —
# 99  666.58 K   59.85 MUSD     —      −0.08USD               +58.94%
#
#    Div yield %TTM                  Sector Analyst Rating
# 0           0.00%  Producer manufacturing        Neutral
# 1           0.00%       Health technology     Strong buy
# 2           0.00%   Distribution services     Strong buy
# 3           0.00%       Health technology        Neutral
# 4           0.00%       Health technology     Strong buy
# ..            ...                     ...            ...
# 95          0.00%       Consumer services     Strong buy
# 96          0.00%       Health technology     Strong buy
# 97          0.00%     Industrial services     Strong buy
# 98          0.00%     Commercial services        Neutral
# 99          0.00%   Electronic technology        Neutral
#
# [100 rows x 12 columns]

# %%
df['Name']=df['Symbol'].str.strip().map(lambda x: x[4:].strip())
df['Symbol']=df['Symbol'].str.strip().map(lambda x: x[:4].strip())

# %%
df.columns
# Out:
# Index(['Symbol', 'Rel Volume', 'Price', 'Change %', 'Volume', 'Market cap',
#        'P/E', 'EPS dilTTM', 'EPS dil growthTTM YoY', 'Div yield %TTM',
#        'Sector', 'Analyst Rating', 'Name'],
#       dtype='object')

# %%
df=df[['Symbol','Name','Rel Volume','Price','Change\xa0%','Volume','Market cap','Sector','Analyst Rating']]

# %%
df
# Out:
#    Symbol                           Name Rel Volume      Price  Change %  \
# 0    INHD             Inno Holdings Inc.   6,120.21    4.75USD  +262.60%
# 1    HCWB             HCW Biologics Inc.   2,639.21    5.55USD   +60.82%
# 2    CAPS         Capstone Holding Corp.     997.08    1.71USD   +55.45%
# 3    EPIX               ESSA Pharma Inc.     288.66  0.7838USD   −59.39%
# 4    STSS         Sharps Technology Inc.     244.83   10.35USD   +40.72%
# ..    ...                            ...        ...        ...       ...
# 95   VENU       Venu Holding Corporation       4.38   14.64USD   −18.35%
# 96   LEXX       Lexaria Bioscience Corp.       4.31    1.05USD   +32.44%
# 97   NCSM  NCS Multistage Holdings, Inc.       4.26   39.49USD    +6.73%
# 98   SUPX  Super X AI Technology Limited       4.24   58.20USD   +35.85%
# 99   ENGS          Energys Group Limited       4.19    4.20USD    +5.00%
#
#       Volume   Market cap                  Sector Analyst Rating
# 0   193.82 M   36.81 MUSD  Producer manufacturing        Neutral
# 1    87.69 M   11.94 MUSD       Health technology     Strong buy
# 2   105.02 M    9.54 MUSD   Distribution services     Strong buy
# 3   178.45 M   37.08 MUSD       Health technology        Neutral
# 4    24.82 M   10.59 MUSD       Health technology     Strong buy
# ..       ...          ...                     ...            ...
# 95  283.54 K  595.72 MUSD       Consumer services     Strong buy
# 96  786.76 K   20.54 MUSD       Health technology     Strong buy
# 97   42.77 K  100.34 MUSD     Industrial services     Strong buy
# 98  823.13 K    1.29 BUSD     Commercial services        Neutral
# 99  666.58 K   59.85 MUSD   Electronic technology        Neutral
#
# [100 rows x 9 columns]
